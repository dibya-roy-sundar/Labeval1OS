# %%
info=dict()

def add_student():
    name=str(input("enter name"))
    sid=int(input("enter student id"))
    cls=str(input("enter class"))
    grades=list()
    avg_grade=0
    for i in range(3):
        x=int(input("enter grade"))
        grades.append(x)
        avg_grade+=x
        
    avg_grade/=3

#     avg_grade=13
        
            
    
    info[sid]=dict(name=name,cls=cls,grades=grades,avg_grade=avg_grade)
    print(info)
    
def update_grades():
    sid=int(input("enter student id"))
    sub_id=int(input("enter subject id"))
    new_val=int(input("enter new grade"))
   
    info[sid]['grades'][sub_id]=new_val
    print(info)
    
def cal_avg():
    sid=int(input("enter student id"))
    print(info[sid]['avg_grade'])


    
def top_performing():
    cls=int(input("enter class"))
    
    cls_stu=list()
    
    for sid in info.keys():
        if info[sid]['cls']==cls:
            cls_stu.append(sid)
    
    cls_stu.sort(key=)
            
            
    

    
    
add_student()
add_student()
add_student()
update_grades()
update_grades()
cal_avg()
cal_avg()
# Out:
# enter namedibya
# enter student id0
# enter class5
# enter grade12
# enter grade13
# enter grade14
# {0: {'name': 'dibya', 'cls': '5', 'grades': [12, 13, 14], 'avg_grade': 13.0}}
# enter namedibya2
# enter student id1
# enter class6
# enter grade45
# enter grade48
# enter grade50
# {0: {'name': 'dibya', 'cls': '5', 'grades': [12, 13, 14], 'avg_grade': 13.0}, 1: {'name': 'dibya2', 'cls': '6', 'grades': [45, 48, 50], 'avg_grade': 47.666666666666664}}
# enter namedibya3
# enter student id2
# enter class7
# enter grade49
# enter grade57
# enter grade45
# {0: {'name': 'dibya', 'cls': '5', 'grades': [12, 13, 14], 'avg_grade': 13.0}, 1: {'name': 'dibya2', 'cls': '6', 'grades': [45, 48, 50], 'avg_grade': 47.666666666666664}, 2: {'name': 'dibya3', 'cls': '7', 'grades': [49, 57, 45], 'avg_grade': 50.333333333333336}}
# enter student id2
# enter subject id2
# enter new grade85
# ...
